# %% [markdown]
# Importing the Libraries

# %%
import pandas as pd

# %% [markdown]
# workinig on the dataset(0) and refining it by deleting the even number row.

# %%
flights=pd.read_csv("D:\\Flask_tutorial\\mytrip\\model\\Flights(old).csv")

# %%
flights.head()
# Out:
#    travelCode  userCode                from                  to  flightType  \
# 0           0         0         Recife (PE)  Florianopolis (SC)  firstClass
# 1           0         0  Florianopolis (SC)         Recife (PE)  firstClass
# 2           1         0       Brasilia (DF)  Florianopolis (SC)  firstClass
# 3           1         0  Florianopolis (SC)       Brasilia (DF)  firstClass
# 4           2         0        Aracaju (SE)       Salvador (BH)  firstClass
#
#      price  time  distance       agency        date
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019
# 1  1292.29  1.76    676.53  FlyingDrops  09/30/2019
# 2  1487.52  1.66    637.56      CloudFy  10/03/2019
# 3  1127.36  1.66    637.56      CloudFy  10/04/2019
# 4  1684.05  2.16    830.86      CloudFy  10/10/2019

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271888 entries, 0 to 271887
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   travelCode  271888 non-null  int64
#  1   userCode    271888 non-null  int64
#  2   from        271888 non-null  object
#  3   to          271888 non-null  object
#  4   flightType  271888 non-null  object
#  5   price       271888 non-null  float64
#  6   time        271888 non-null  float64
#  7   distance    271888 non-null  float64
#  8   agency      271888 non-null  object
#  9   date        271888 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 20.7+ MB

# %% [markdown]
# here the dataset contains the data about the round trip so eliminating the other half of the data.

# %%
df_odd_row=flights.iloc[::2]
df_odd_row.head()
# Out:
#    travelCode  userCode           from                  to  flightType  \
# 0           0         0    Recife (PE)  Florianopolis (SC)  firstClass
# 2           1         0  Brasilia (DF)  Florianopolis (SC)  firstClass
# 4           2         0   Aracaju (SE)       Salvador (BH)  firstClass
# 6           3         0   Aracaju (SE)   Campo Grande (MS)    economic
# 8           4         0    Recife (PE)  Florianopolis (SC)    economic
#
#      price  time  distance       agency        date
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019
# 2  1487.52  1.66    637.56      CloudFy  10/03/2019
# 4  1684.05  2.16    830.86      CloudFy  10/10/2019
# 6   743.54  1.69    650.10      Rainbow  10/17/2019
# 8   803.39  1.76    676.53      Rainbow  10/24/2019

# %%
flights_odd=df_odd_row

# %%
flights_odd.head()
# Out:
#    travelCode  userCode           from                  to  flightType  \
# 0           0         0    Recife (PE)  Florianopolis (SC)  firstClass
# 2           1         0  Brasilia (DF)  Florianopolis (SC)  firstClass
# 4           2         0   Aracaju (SE)       Salvador (BH)  firstClass
# 6           3         0   Aracaju (SE)   Campo Grande (MS)    economic
# 8           4         0    Recife (PE)  Florianopolis (SC)    economic
#
#      price  time  distance       agency        date
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019
# 2  1487.52  1.66    637.56      CloudFy  10/03/2019
# 4  1684.05  2.16    830.86      CloudFy  10/10/2019
# 6   743.54  1.69    650.10      Rainbow  10/17/2019
# 8   803.39  1.76    676.53      Rainbow  10/24/2019

# %%
flights_odd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135944 entries, 0 to 271886
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   travelCode  135944 non-null  int64
#  1   userCode    135944 non-null  int64
#  2   from        135944 non-null  object
#  3   to          135944 non-null  object
#  4   flightType  135944 non-null  object
#  5   price       135944 non-null  float64
#  6   time        135944 non-null  float64
#  7   distance    135944 non-null  float64
#  8   agency      135944 non-null  object
#  9   date        135944 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 10.4+ MB

# %% [markdown]
# Loading the hotels dataset:

# %%
hotel_df=pd.read_csv("D:\\Flask_tutorial\\mytrip\\model\\hotels.csv")

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40552 entries, 0 to 40551
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   travelCode  40552 non-null  int64
#  1   userCode    40552 non-null  int64
#  2   name        40552 non-null  object
#  3   place       40552 non-null  object
#  4   days        40552 non-null  int64
#  5   price       40552 non-null  float64
#  6   total       40552 non-null  float64
#  7   date        40552 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 2.5+ MB

# %%
hotel_df.head()
# Out:
#    travelCode  userCode     name               place  days   price    total  \
# 0           0         0  Hotel A  Florianopolis (SC)     4  313.02  1252.08
# 1           2         0  Hotel K       Salvador (BH)     2  263.41   526.82
# 2           7         0  Hotel K       Salvador (BH)     3  263.41   790.23
# 3          11         0  Hotel K       Salvador (BH)     4  263.41  1053.64
# 4          13         0  Hotel A  Florianopolis (SC)     1  313.02   313.02
#
#          date
# 0  09/26/2019
# 1  10/10/2019
# 2  11/14/2019
# 3  12/12/2019
# 4  12/26/2019

# %%
flight_hotel_df=pd.merge(flights_odd,hotel_df,on='travelCode',how='inner') # merging the flights and hotel dataframes
flight_hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40552 entries, 0 to 40551
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   travelCode  40552 non-null  int64
#  1   userCode_x  40552 non-null  int64
#  2   from        40552 non-null  object
#  3   to          40552 non-null  object
#  4   flightType  40552 non-null  object
#  5   price_x     40552 non-null  float64
#  6   time        40552 non-null  float64
#  7   distance    40552 non-null  float64
#  8   agency      40552 non-null  object
#  9   date_x      40552 non-null  object
#  10  userCode_y  40552 non-null  int64
#  11  name        40552 non-null  object
#  12  place       40552 non-null  object
#  13  days        40552 non-null  int64
#  14  price_y     40552 non-null  float64
#  15  total       40552 non-null  float64
#  16  date_y      40552 non-null  object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 5.3+ MB

# %%
print(flight_hotel_df.head())
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  userCode_y     name  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019           0  Hotel A
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019           0  Hotel K
# 2   964.83  2.16    830.86      CloudFy  11/14/2019           0  Hotel K
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019           0  Hotel K
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019           0  Hotel A
#
#                 place  days  price_y    total      date_y
# ...

# %%
flight_hotel_df.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  userCode_y     name  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019           0  Hotel A
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019           0  Hotel K
# 2   964.83  2.16    830.86      CloudFy  11/14/2019           0  Hotel K
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019           0  Hotel K
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019           0  Hotel A
#
#                 place  days  price_y    total      date_y
# ...

# %%
users_df=pd.read_csv("D:\\Flask_tutorial\\mytrip\\model\\users.csv")

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   code     1340 non-null   int64
#  1   company  1340 non-null   object
#  2   name     1340 non-null   object
#  3   gender   1340 non-null   object
#  4   age      1340 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 52.5+ KB

# %%
users_df.head()
# Out:
#    code company             name  gender  age
# 0     0    4You        Roy Braun    male   21
# 1     1    4You   Joseph Holsten    male   37
# 2     2    4You    Wilma Mcinnis  female   48
# 3     3    4You     Paula Daniel  female   23
# 4     4    4You  Patricia Carson  female   44

# %%
flight_hotel_user= pd.merge(flight_hotel_df,users_df,left_on="userCode_x",right_on="code",how="inner")# merge the previously merged flights and hotel data with the users dataframe into one.
flight_hotel_user.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ...               place  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...  Florianopolis (SC)
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...       Salvador (BH)
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...       Salvador (BH)
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...       Salvador (BH)
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...  Florianopolis (SC)
#
# ...

# %%
flight_hotel_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40552 entries, 0 to 40551
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   travelCode  40552 non-null  int64
#  1   userCode_x  40552 non-null  int64
#  2   from        40552 non-null  object
#  3   to          40552 non-null  object
#  4   flightType  40552 non-null  object
#  5   price_x     40552 non-null  float64
#  6   time        40552 non-null  float64
#  7   distance    40552 non-null  float64
#  8   agency      40552 non-null  object
#  9   date_x      40552 non-null  object
#  10  userCode_y  40552 non-null  int64
#  11  name_x      40552 non-null  object
#  12  place       40552 non-null  object
#  13  days        40552 non-null  int64
#  14  price_y     40552 non-null  float64
#  15  total       40552 non-null  float64
#  16  date_y      40552 non-null  object
#  17  code        40552 non-null  int64
#  18  company     40552 non-null  object
# ...

# %%
print(flight_hotel_user.head())
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ...               place  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...  Florianopolis (SC)
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...       Salvador (BH)
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...       Salvador (BH)
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...       Salvador (BH)
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...  Florianopolis (SC)
#
# ...

# %%
# saving the dataframe to current directory
flight_hotel_user.to_csv('file1.csv')

# %% [markdown]
# #### !!Note: the file1.csv is the merged dataset.

# %%
# load the car_rental dataset:
car_rent=pd.read_csv("D:\\Flask_tutorial\\mytrip\\model\\Rent_a_car (old).csv")

# %%
car_rent.head()
# Out:
#    travelCode  code   pickupLocation dropoffLocation carType rentalAgency  \
# 0      126191   195       Aliciabury       Lopezbury   Sedan   Enterprise
# 1       18474  1086   Edwardsborough    North Daniel     SUV         Sixt
# 2       90427    90  West Danielside      Riverafort   Sedan         Avis
# 3      123934    75   North Samantha    North Joseph  Luxury         Sixt
# 4       98809   300         Cobbview     Amandaburgh  Luxury         Sixt
#
#         pickupDateTime      dropoffDateTime  rentalDuration   price  \
# 0  2025-01-19 02:43:34  2025-01-24 02:43:34               5  284.56
# 1  2025-01-01 07:31:29  2025-01-03 07:31:29               2  176.83
# 2  2025-01-02 22:37:32  2025-01-05 22:37:32               3  236.79
# 3  2025-01-16 18:57:49  2025-01-21 18:57:49               5  781.64
# 4  2025-01-20 22:53:00  2025-01-25 22:53:00               5  597.22
#
#    totalDistance    fuelPolicy bookingStatus
# 0            371       Prepaid     Cancelled
# ...

# %%
car_rent.columns
# Out:
# Index(['travelCode', 'code', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'pickupDateTime', 'dropoffDateTime', 'rentalDuration',
#        'price', 'totalDistance', 'fuelPolicy', 'bookingStatus'],
#       dtype='object')

# %% [markdown]
# below merged dataset can be used for recommending the user a car rental who have not yet booked a car but booked a flight and hotel.

# %%
flight_hotel_user_car_l=pd.merge(flight_hotel_user,car_rent,on="travelCode",how="left")
flight_hotel_user_car_l.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ...  dropoffLocation  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...              NaN
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...              NaN
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...              NaN
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...              NaN
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...              NaN
#
#   carType rentalAgency  pickupDateTime  dropoffDateTime  rentalDuration price  \
# ...

# %%
#the following code is to be executed only once.
# flight_hotel_user_car_l.to_csv("cars_merged.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 flight_hotel_user_car_l.to_csv("cars_merged.csv")
#
# File c:\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:3961, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
# ...

# %%
flight_hotel_user_car_l.shape#left join
# Out:
# (40738, 34)

# %%
flight_hotel_user_car_i=pd.merge(flight_hotel_user,car_rent,on="travelCode",how="inner")
flight_hotel_user_car_i.head()# inner join
# Out:
#    travelCode  userCode_x           from                 to  flightType  \
# 0          22           0  Brasilia (DF)       Aracaju (SE)  firstClass
# 1          45           0    Recife (PE)         Natal (RN)     premium
# 2         117           2   Aracaju (SE)        Recife (PE)    economic
# 3         119           2   Aracaju (SE)      Salvador (BH)  firstClass
# 4         153           2   Aracaju (SE)  Campo Grande (MS)     premium
#
#    price_x  time  distance   agency      date_x  ...  dropoffLocation  \
# 0  1214.82  1.11    425.98  Rainbow  02/27/2020  ...       Port Brian
# 1   474.60  0.58    222.67  CloudFy  08/06/2020  ...         Ruizfort
# 2   602.49  1.44    555.74  Rainbow  02/27/2020  ...        Katiefort
# 3  1723.71  2.16    830.86  Rainbow  03/12/2020  ...   Lake Stephanie
# 4  1021.53  1.69    650.10  CloudFy  11/05/2020  ...  East Ronnieberg
#
#      carType rentalAgency       pickupDateTime      dropoffDateTime  \
# ...

# %%
flight_hotel_user_car_i.shape
# Out:
# (3959, 34)

# %%
flight_hotel_user_car_r=pd.merge(flight_hotel_user,car_rent,on="travelCode",how="right")
flight_hotel_user_car_r.head()
# Out:
#    travelCode  userCode_x                from           to flightType  \
# 0      126191         NaN                 NaN          NaN        NaN
# 1       18474         NaN                 NaN          NaN        NaN
# 2       90427       892.0  Florianopolis (SC)  Recife (PE)    premium
# 3      123934         NaN                 NaN          NaN        NaN
# 4       98809         NaN                 NaN          NaN        NaN
#
#    price_x  time  distance   agency      date_x  ...  dropoffLocation carType  \
# 0      NaN   NaN       NaN      NaN         NaN  ...        Lopezbury   Sedan
# 1      NaN   NaN       NaN      NaN         NaN  ...     North Daniel     SUV
# 2   918.66  1.76    676.53  CloudFy  08/27/2020  ...       Riverafort   Sedan
# 3      NaN   NaN       NaN      NaN         NaN  ...     North Joseph  Luxury
# 4      NaN   NaN       NaN      NaN         NaN  ...      Amandaburgh  Luxury
#
#   rentalAgency       pickupDateTime      dropoffDateTime  rentalDuration  \
# ...

# %%
flight_hotel_user_car_r.shape
# Out:
# (10000, 34)

# %%
flight_hotel_user_car_l.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'userCode_y', 'name_x', 'place',
#        'days', 'price_y', 'total', 'date_y', 'code_x', 'company', 'name_y',
#        'gender', 'age', 'code_y', 'pickupLocation', 'dropoffLocation',
#        'carType', 'rentalAgency', 'pickupDateTime', 'dropoffDateTime',
#        'rentalDuration', 'price', 'totalDistance', 'fuelPolicy',
#        'bookingStatus'],
#       dtype='object')

# %%
# code to delete the dates
flight_hotel_user_car_l.drop(["pickupDateTime","dropoffDateTime"],axis=1)
# Out:
#        travelCode  userCode_x                from                  to  \
# 0               0           0         Recife (PE)  Florianopolis (SC)
# 1               2           0        Aracaju (SE)       Salvador (BH)
# 2               7           0        Aracaju (SE)       Salvador (BH)
# 3              11           0       Brasilia (DF)       Salvador (BH)
# 4              13           0         Recife (PE)  Florianopolis (SC)
# ...           ...         ...                 ...                 ...
# 40733      135938        1339  Florianopolis (SC)       Brasilia (DF)
# 40734      135939        1339  Florianopolis (SC)       Brasilia (DF)
# 40735      135940        1339  Florianopolis (SC)   Campo Grande (MS)
# 40736      135941        1339  Florianopolis (SC)   Campo Grande (MS)
# 40737      135942        1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  price_x  time  distance       agency      date_x  ...  \
# ...

# %%
flight_hotel_user_car_l.drop(["userCode_y","code_x"],axis=1)
flight_hotel_user_car_l
# Out:
#        travelCode  userCode_x                from                  to  \
# 0               0           0         Recife (PE)  Florianopolis (SC)
# 1               2           0        Aracaju (SE)       Salvador (BH)
# 2               7           0        Aracaju (SE)       Salvador (BH)
# 3              11           0       Brasilia (DF)       Salvador (BH)
# 4              13           0         Recife (PE)  Florianopolis (SC)
# ...           ...         ...                 ...                 ...
# 40733      135938        1339  Florianopolis (SC)       Brasilia (DF)
# 40734      135939        1339  Florianopolis (SC)       Brasilia (DF)
# 40735      135940        1339  Florianopolis (SC)   Campo Grande (MS)
# 40736      135941        1339  Florianopolis (SC)   Campo Grande (MS)
# 40737      135942        1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  price_x  time  distance       agency      date_x  ...  \
# ...

# %%
flight_hotel_user_car_l.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'userCode_y', 'name_x', 'place',
#        'days', 'price_y', 'total', 'date_y', 'code_x', 'company', 'name_y',
#        'gender', 'age', 'code_y', 'pickupLocation', 'dropoffLocation',
#        'carType', 'rentalAgency', 'pickupDateTime', 'dropoffDateTime',
#        'rentalDuration', 'price', 'totalDistance', 'fuelPolicy',
#        'bookingStatus'],
#       dtype='object')

# %%
flight_hotel_user_car_l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   travelCode       40738 non-null  int64
#  1   userCode_x       40738 non-null  int64
#  2   from             40738 non-null  object
#  3   to               40738 non-null  object
#  4   flightType       40738 non-null  object
#  5   price_x          40738 non-null  float64
#  6   time             40738 non-null  float64
#  7   distance         40738 non-null  float64
#  8   agency           40738 non-null  object
#  9   date_x           40738 non-null  object
#  10  userCode_y       40738 non-null  int64
#  11  name_x           40738 non-null  object
#  12  place            40738 non-null  object
#  13  days             40738 non-null  int64
#  14  price_y          40738 non-null  float64
#  15  total            40738 non-null  float64
# ...

# %% [markdown]
# calculating the total price by adding the price of flight,hotel and car rent.

# %%
flight_hotel_user_car_l["total_price"]=flight_hotel_user_car_l["price_x"]+flight_hotel_user_car_l["price_y"]+flight_hotel_user_car_l["price"]

# %%
flight_hotel_user_car_l.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ...  carType  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...      NaN
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...      NaN
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...      NaN
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...      NaN
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...      NaN
#
#   rentalAgency pickupDateTime  dropoffDateTime  rentalDuration  price  \
# ...

# %%
flight_hotel_user_car_l.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'userCode_y', 'name_x', 'place',
#        'days', 'price_y', 'total', 'date_y', 'code_x', 'company', 'name_y',
#        'gender', 'age', 'code_y', 'pickupLocation', 'dropoffLocation',
#        'carType', 'rentalAgency', 'pickupDateTime', 'dropoffDateTime',
#        'rentalDuration', 'price', 'totalDistance', 'fuelPolicy',
#        'bookingStatus', 'total_price'],
#       dtype='object')

# %%
df=pd.read_csv("D:\\Make_my_trip\\cars_merged.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'travelCode', 'userCode_x', 'from', 'to', 'flightType',
#        'price_x', 'time', 'distance', 'agency', 'date_x', 'userCode_y',
#        'name_x', 'place', 'days', 'price_y', 'total', 'date_y', 'code_x',
#        'company', 'name_y', 'gender', 'age', 'code_y', 'pickupLocation',
#        'dropoffLocation', 'carType', 'rentalAgency', 'pickupDateTime',
#        'dropoffDateTime', 'rentalDuration', 'price', 'totalDistance',
#        'fuelPolicy', 'bookingStatus'],
#       dtype='object')

# %%
new=df.drop(["Unnamed: 0","userCode_y","code_x","pickupDateTime","dropoffDateTime"],axis=1)

# %%
new.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'name_x', 'place', 'days',
#        'price_y', 'total', 'date_y', 'company', 'name_y', 'gender', 'age',
#        'code_y', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'rentalDuration', 'price', 'totalDistance',
#        'fuelPolicy', 'bookingStatus'],
#       dtype='object')

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 30 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   travelCode       40738 non-null  int64
#  1   userCode_x       40738 non-null  int64
#  2   from             40738 non-null  object
#  3   to               40738 non-null  object
#  4   flightType       40738 non-null  object
#  5   price_x          40738 non-null  float64
#  6   time             40738 non-null  float64
#  7   distance         40738 non-null  float64
#  8   agency           40738 non-null  object
#  9   date_x           40738 non-null  object
#  10  name_x           40738 non-null  object
#  11  place            40738 non-null  object
#  12  days             40738 non-null  int64
#  13  price_y          40738 non-null  float64
#  14  total            40738 non-null  float64
#  15  date_y           40738 non-null  object
# ...

# %%
new["total_price"]=new["price_x"]+new["price_y"]+new["price"]

# %%
new.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ... pickupLocation  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...            NaN
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...            NaN
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...            NaN
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...            NaN
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...            NaN
#
#   dropoffLocation  carType  rentalAgency  rentalDuration price totalDistance  \
# ...

# %%
new.to_csv('data_0.csv', index=False)

# %%
data_0=pd.read_csv("data_0.csv")

# %%
data_0.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'name_x', 'place', 'days',
#        'price_y', 'total', 'date_y', 'company', 'name_y', 'gender', 'age',
#        'code_y', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'rentalDuration', 'price', 'totalDistance',
#        'fuelPolicy', 'bookingStatus', 'total_price'],
#       dtype='object')

# %% [markdown]
# ###### renaming the column names to indicate the entities:

# %%
data_0.columns = data_0.columns.str.replace(' _x', '_flights')

# %%
data_0.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'name_x', 'place', 'days',
#        'price_y', 'total', 'date_y', 'company', 'name_y', 'gender', 'age',
#        'code_y', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'rentalDuration', 'price', 'totalDistance',
#        'fuelPolicy', 'bookingStatus', 'total_price'],
#       dtype='object')

# %%
data_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   travelCode       40738 non-null  int64
#  1   userCode_x       40738 non-null  int64
#  2   from             40738 non-null  object
#  3   to               40738 non-null  object
#  4   flightType       40738 non-null  object
#  5   price_x          40738 non-null  float64
#  6   time             40738 non-null  float64
#  7   distance         40738 non-null  float64
#  8   agency           40738 non-null  object
#  9   date_x           40738 non-null  object
#  10  name_x           40738 non-null  object
#  11  place            40738 non-null  object
#  12  days             40738 non-null  int64
#  13  price_y          40738 non-null  float64
#  14  total            40738 non-null  float64
#  15  date_y           40738 non-null  object
# ...

# %%
data_1=data_0.drop(["code_y"],axis=1)

# %%
data_1.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ... pickupLocation  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...            NaN
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...            NaN
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...            NaN
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...            NaN
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...            NaN
#
#   dropoffLocation  carType  rentalAgency  rentalDuration price totalDistance  \
# ...

# %%
data_1.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'to', 'flightType', 'price_x',
#        'time', 'distance', 'agency', 'date_x', 'name_x', 'place', 'days',
#        'price_y', 'total', 'date_y', 'company', 'name_y', 'gender', 'age',
#        'pickupLocation', 'dropoffLocation', 'carType', 'rentalAgency',
#        'rentalDuration', 'price', 'totalDistance', 'fuelPolicy',
#        'bookingStatus', 'total_price'],
#       dtype='object')

# %%
data_1 = data_1.rename(columns={'userCode': 'user_id', 'from ': 'departure', 'to': 'arrival','price_x':'flight_price','time':'flight_duration','date_x':'flight_date','name_x':'hotel_name','place':'hotel_place','price_y':'hotel_base','total':'total_hotel','date_y':'check_in','name_y':'user_name','price':'car_price'})

# %%
data_1.columns
# Out:
# Index(['travelCode', 'userCode_x', 'from', 'arrival', 'flightType',
#        'flight_price', 'flight_duration', 'distance', 'agency', 'flight_date',
#        'hotel_name', 'hotel_place', 'days', 'hotel_base', 'total_hotel',
#        'check_in', 'company', 'user_name', 'gender', 'age', 'pickupLocation',
#        'dropoffLocation', 'carType', 'rentalAgency', 'rentalDuration',
#        'car_price', 'totalDistance', 'fuelPolicy', 'bookingStatus',
#        'total_price'],
#       dtype='object')

# %%
data_1=data_1.rename(columns={'userCode_x':'user_id','from':'departure'})

# %%
data_1.columns
# Out:
# Index(['travelCode', 'user_id', 'departure', 'arrival', 'flightType',
#        'flight_price', 'flight_duration', 'distance', 'agency', 'flight_date',
#        'hotel_name', 'hotel_place', 'days', 'hotel_base', 'total_hotel',
#        'check_in', 'company', 'user_name', 'gender', 'age', 'pickupLocation',
#        'dropoffLocation', 'carType', 'rentalAgency', 'rentalDuration',
#        'car_price', 'totalDistance', 'fuelPolicy', 'bookingStatus',
#        'total_price'],
#       dtype='object')

# %%
data_1.to_csv("dataset_0.csv",index=False)

# %%
data_1['total_price'] = data_1[['flight_price', 'total_hotel', 'car_price']].sum(axis=1, skipna=True)

# %%
data_1.head()
# Out:
#    travelCode  user_id      departure             arrival  flightType  \
# 0           0        0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2        0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7        0   Aracaju (SE)       Salvador (BH)    economic
# 3          11        0  Brasilia (DF)       Salvador (BH)     premium
# 4          13        0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    flight_price  flight_duration  distance       agency flight_date  ...  \
# 0       1434.38             1.76    676.53  FlyingDrops  09/26/2019  ...
# 1       1684.05             2.16    830.86      CloudFy  10/10/2019  ...
# 2        964.83             2.16    830.86      CloudFy  11/14/2019  ...
# 3       1268.97             1.76    676.56      Rainbow  12/12/2019  ...
# 4       1434.38             1.76    676.53  FlyingDrops  12/26/2019  ...
#
#   pickupLocation dropoffLocation  carType  rentalAgency  rentalDuration  \
# ...

# %% [markdown]
# car rent data:

# %%
car=pd.read_csv("D:\\Flask_tutorial\\mytrip\\model\\Rent_a_car (old).csv")

# %%
car.columns
# Out:
# Index(['travelCode', 'code', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'pickupDateTime', 'dropoffDateTime', 'rentalDuration',
#        'price', 'totalDistance', 'fuelPolicy', 'bookingStatus'],
#       dtype='object')

# %%
car_1=car.drop(["pickupDateTime","dropoffDateTime"],axis=1)

# %%
car_1.drop(["price"],axis=1)
# Out:
#       travelCode  code     pickupLocation   dropoffLocation    carType  \
# 0         126191   195         Aliciabury         Lopezbury      Sedan
# 1          18474  1086     Edwardsborough      North Daniel        SUV
# 2          90427    90    West Danielside        Riverafort      Sedan
# 3         123934    75     North Samantha      North Joseph     Luxury
# 4          98809   300           Cobbview       Amandaburgh     Luxury
# ...          ...   ...                ...               ...        ...
# 9995         407   558  North Destinybury        West Tyler        SUV
# 9996      114887  1256        Williamside        New Ashley      Sedan
# 9997       40666   280     North Alexbury       Mortonville      Sedan
# 9998      115752   424          Clarkfurt  East Christopher  Hatchback
# 9999       39934  1318     Blackwellshire      Nicholasfurt     Luxury
#
#      rentalAgency  rentalDuration  totalDistance    fuelPolicy bookingStatus
# ...

# %%
cars=car_1

# %%
pricing = {
    'Not Rented': {'base_fare': 0, 'rate_per_hour': 0, 'rate_per_km': 0},
    'Hatchback': {'base_fare': 200, 'rate_per_hour': 50, 'rate_per_km': 8},
    'Sedan': {'base_fare': 300, 'rate_per_hour': 70, 'rate_per_km': 10},
    'SUV': {'base_fare': 400, 'rate_per_hour': 90, 'rate_per_km': 12},
    'Luxury': {'base_fare': 800, 'rate_per_hour': 150, 'rate_per_km': 20},
}

# %%
cars.columns
# Out:
# Index(['travelCode', 'code', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'rentalDuration', 'price', 'totalDistance',
#        'fuelPolicy', 'bookingStatus'],
#       dtype='object')

# %%
import numpy as np

# %%
def calculate_rent(row):
    car = row['carType']
    
    # Handle cases where carType is not in pricing dictionary
    if car not in pricing or pd.isna(car) or car == 'Not Rented':
        return 0.0  # No charge for Not Rented cars
    
    base_fare = pricing[car]['base_fare']
    rate_per_hour = pricing[car]['rate_per_hour']
    rate_per_km = pricing[car]['rate_per_km']

    # Handle NaN values by replacing with 0
    rental_duration = row['rentalDuration'] if not pd.isna(row['rentalDuration']) else 0
    distance = row['totalDistance'] if not pd.isna(row['totalDistance']) else 0

    # Calculate total price
    total_price = (
        base_fare +
        (rental_duration * rate_per_hour) +
        (distance * rate_per_km) +
        np.random.randint(10, 51)  # Random charge between 10 and 50
    )
    
    return total_price

# Apply function
cars['total_rent_price'] = cars.apply(calculate_rent, axis=1)

# %%
cars.head()
# Out:
#    travelCode  code   pickupLocation dropoffLocation carType rentalAgency  \
# 0      126191   195       Aliciabury       Lopezbury   Sedan   Enterprise
# 1       18474  1086   Edwardsborough    North Daniel     SUV         Sixt
# 2       90427    90  West Danielside      Riverafort   Sedan         Avis
# 3      123934    75   North Samantha    North Joseph  Luxury         Sixt
# 4       98809   300         Cobbview     Amandaburgh  Luxury         Sixt
#
#    rentalDuration   price  totalDistance    fuelPolicy bookingStatus  \
# 0               5  284.56            371       Prepaid     Cancelled
# 1               2  176.83            461  Full-to-Full       Pending
# 2               3  236.79            383       Prepaid     Confirmed
# 3               5  781.64            294       Partial       Pending
# 4               5  597.22            488       Partial     Cancelled
#
#    total_rent_price
# 0              4376
# 1              6126
# 2              4387
# ...

# %%
flight_hotel_user_cars_l=pd.merge(flight_hotel_user,cars,on="travelCode",how="left")
flight_hotel_user_cars_l.head()
# Out:
#    travelCode  userCode_x           from                  to  flightType  \
# 0           0           0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2           0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7           0   Aracaju (SE)       Salvador (BH)    economic
# 3          11           0  Brasilia (DF)       Salvador (BH)     premium
# 4          13           0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    price_x  time  distance       agency      date_x  ...  pickupLocation  \
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019  ...             NaN
# 1  1684.05  2.16    830.86      CloudFy  10/10/2019  ...             NaN
# 2   964.83  2.16    830.86      CloudFy  11/14/2019  ...             NaN
# 3  1268.97  1.76    676.56      Rainbow  12/12/2019  ...             NaN
# 4  1434.38  1.76    676.53  FlyingDrops  12/26/2019  ...             NaN
#
#   dropoffLocation carType  rentalAgency  rentalDuration  price totalDistance  \
# ...

# %%
flight_hotel_user_cars_l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   travelCode        40738 non-null  int64
#  1   userCode_x        40738 non-null  int64
#  2   from              40738 non-null  object
#  3   to                40738 non-null  object
#  4   flightType        40738 non-null  object
#  5   price_x           40738 non-null  float64
#  6   time              40738 non-null  float64
#  7   distance          40738 non-null  float64
#  8   agency            40738 non-null  object
#  9   date_x            40738 non-null  object
#  10  userCode_y        40738 non-null  int64
#  11  name_x            40738 non-null  object
#  12  place             40738 non-null  object
#  13  days              40738 non-null  int64
#  14  price_y           40738 non-null  float64
#  15  total             40738 non-null  float64
# ...

# %%
final_df=flight_hotel_user_cars_l

# %%
final_df = final_df.rename(columns={'userCode_x': 'user_id', 'from': 'departure', 'to': 'arrival','price_x':'flight_price','time':'flight_duration','date_x':'flight_date','name_x':'hotel_name','place':'hotel_place','price_y':'hotel_base','total':'total_hotel','date_y':'check_in','name_y':'user_name','price':'car_price'})

# %%
final_df['total_price'] = final_df[['flight_price', 'total_hotel', 'car_price']].sum(axis=1, skipna=True)

# %%
final_df.head()
# Out:
#    travelCode  user_id      departure             arrival  flightType  \
# 0           0        0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2        0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7        0   Aracaju (SE)       Salvador (BH)    economic
# 3          11        0  Brasilia (DF)       Salvador (BH)     premium
# 4          13        0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    flight_price  flight_duration  distance       agency flight_date  ...  \
# 0       1434.38             1.76    676.53  FlyingDrops  09/26/2019  ...
# 1       1684.05             2.16    830.86      CloudFy  10/10/2019  ...
# 2        964.83             2.16    830.86      CloudFy  11/14/2019  ...
# 3       1268.97             1.76    676.56      Rainbow  12/12/2019  ...
# 4       1434.38             1.76    676.53  FlyingDrops  12/26/2019  ...
#
#    dropoffLocation carType rentalAgency  rentalDuration  car_price  \
# ...

# %%
final_df.to_csv("new_dataset.csv",index=False)

# %%
final_df.drop(["code_y"],axis=1)
# Out:
#        travelCode  user_id           departure             arrival  \
# 0               0        0         Recife (PE)  Florianopolis (SC)
# 1               2        0        Aracaju (SE)       Salvador (BH)
# 2               7        0        Aracaju (SE)       Salvador (BH)
# 3              11        0       Brasilia (DF)       Salvador (BH)
# 4              13        0         Recife (PE)  Florianopolis (SC)
# ...           ...      ...                 ...                 ...
# 40733      135938     1339  Florianopolis (SC)       Brasilia (DF)
# 40734      135939     1339  Florianopolis (SC)       Brasilia (DF)
# 40735      135940     1339  Florianopolis (SC)   Campo Grande (MS)
# 40736      135941     1339  Florianopolis (SC)   Campo Grande (MS)
# 40737      135942     1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  flight_price  flight_duration  distance       agency  \
# 0      firstClass       1434.38             1.76    676.53  FlyingDrops
# ...

# %%
final_df.to_csv("final_ds.csv",index=False)

# %%
final_df.columns
# Out:
# Index(['travelCode', 'user_id', 'departure', 'arrival', 'flightType',
#        'flight_price', 'flight_duration', 'distance', 'agency', 'flight_date',
#        'userCode_y', 'hotel_name', 'hotel_place', 'days', 'hotel_base',
#        'total_hotel', 'check_in', 'code_x', 'company', 'user_name', 'gender',
#        'age', 'code_y', 'pickupLocation', 'dropoffLocation', 'carType',
#        'rentalAgency', 'rentalDuration', 'car_price', 'totalDistance',
#        'fuelPolicy', 'bookingStatus', 'total_rent_price', 'total_price'],
#       dtype='object')

# %%
final_1=final_df.drop(["userCode_y","code_x","code_y"],axis=1)

# %%
final_1.columns
# Out:
# Index(['travelCode', 'user_id', 'departure', 'arrival', 'flightType',
#        'flight_price', 'flight_duration', 'distance', 'agency', 'flight_date',
#        'hotel_name', 'hotel_place', 'days', 'hotel_base', 'total_hotel',
#        'check_in', 'company', 'user_name', 'gender', 'age', 'pickupLocation',
#        'dropoffLocation', 'carType', 'rentalAgency', 'rentalDuration',
#        'car_price', 'totalDistance', 'fuelPolicy', 'bookingStatus',
#        'total_rent_price', 'total_price'],
#       dtype='object')

# %%
final_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   travelCode        40738 non-null  int64
#  1   user_id           40738 non-null  int64
#  2   departure         40738 non-null  object
#  3   arrival           40738 non-null  object
#  4   flightType        40738 non-null  object
#  5   flight_price      40738 non-null  float64
#  6   flight_duration   40738 non-null  float64
#  7   distance          40738 non-null  float64
#  8   agency            40738 non-null  object
#  9   flight_date       40738 non-null  object
#  10  hotel_name        40738 non-null  object
#  11  hotel_place       40738 non-null  object
#  12  days              40738 non-null  int64
#  13  hotel_base        40738 non-null  float64
#  14  total_hotel       40738 non-null  float64
#  15  check_in          40738 non-null  object
# ...

# %%
final_2=final_1.drop(["car_price"],axis=1)

# %%
final_2.columns
# Out:
# Index(['travelCode', 'user_id', 'departure', 'arrival', 'flightType',
#        'flight_price', 'flight_duration', 'distance', 'agency', 'flight_date',
#        'hotel_name', 'hotel_place', 'days', 'hotel_base', 'total_hotel',
#        'check_in', 'company', 'user_name', 'gender', 'age', 'pickupLocation',
#        'dropoffLocation', 'carType', 'rentalAgency', 'rentalDuration',
#        'totalDistance', 'fuelPolicy', 'bookingStatus', 'total_rent_price',
#        'total_price'],
#       dtype='object')

# %%
final_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   travelCode        40738 non-null  int64
#  1   user_id           40738 non-null  int64
#  2   departure         40738 non-null  object
#  3   arrival           40738 non-null  object
#  4   flightType        40738 non-null  object
#  5   flight_price      40738 non-null  float64
#  6   flight_duration   40738 non-null  float64
#  7   distance          40738 non-null  float64
#  8   agency            40738 non-null  object
#  9   flight_date       40738 non-null  object
#  10  hotel_name        40738 non-null  object
#  11  hotel_place       40738 non-null  object
#  12  days              40738 non-null  int64
#  13  hotel_base        40738 non-null  float64
#  14  total_hotel       40738 non-null  float64
#  15  check_in          40738 non-null  object
# ...

# %%
final_2.head()
# Out:
#    travelCode  user_id      departure             arrival  flightType  \
# 0           0        0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2        0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7        0   Aracaju (SE)       Salvador (BH)    economic
# 3          11        0  Brasilia (DF)       Salvador (BH)     premium
# 4          13        0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    flight_price  flight_duration  distance       agency flight_date  ...  \
# 0       1434.38             1.76    676.53  FlyingDrops  09/26/2019  ...
# 1       1684.05             2.16    830.86      CloudFy  10/10/2019  ...
# 2        964.83             2.16    830.86      CloudFy  11/14/2019  ...
# 3       1268.97             1.76    676.56      Rainbow  12/12/2019  ...
# 4       1434.38             1.76    676.53  FlyingDrops  12/26/2019  ...
#
#   pickupLocation dropoffLocation  carType  rentalAgency  rentalDuration  \
# ...

# %%
final_2.to_csv("1.csv",index=False)

# %%
final_2['total_price'] = final_2[['flight_price', 'total_hotel', 'total_rent_price']].sum(axis=1, skipna=True)

# %%
final_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   travelCode        40738 non-null  int64
#  1   user_id           40738 non-null  int64
#  2   departure         40738 non-null  object
#  3   arrival           40738 non-null  object
#  4   flightType        40738 non-null  object
#  5   flight_price      40738 non-null  float64
#  6   flight_duration   40738 non-null  float64
#  7   distance          40738 non-null  float64
#  8   agency            40738 non-null  object
#  9   flight_date       40738 non-null  object
#  10  hotel_name        40738 non-null  object
#  11  hotel_place       40738 non-null  object
#  12  days              40738 non-null  int64
#  13  hotel_base        40738 non-null  float64
#  14  total_hotel       40738 non-null  float64
#  15  check_in          40738 non-null  object
# ...

# %%
final_2.head()
# Out:
#    travelCode  user_id      departure             arrival  flightType  \
# 0           0        0    Recife (PE)  Florianopolis (SC)  firstClass
# 1           2        0   Aracaju (SE)       Salvador (BH)  firstClass
# 2           7        0   Aracaju (SE)       Salvador (BH)    economic
# 3          11        0  Brasilia (DF)       Salvador (BH)     premium
# 4          13        0    Recife (PE)  Florianopolis (SC)  firstClass
#
#    flight_price  flight_duration  distance       agency flight_date  ...  \
# 0       1434.38             1.76    676.53  FlyingDrops  09/26/2019  ...
# 1       1684.05             2.16    830.86      CloudFy  10/10/2019  ...
# 2        964.83             2.16    830.86      CloudFy  11/14/2019  ...
# 3       1268.97             1.76    676.56      Rainbow  12/12/2019  ...
# 4       1434.38             1.76    676.53  FlyingDrops  12/26/2019  ...
#
#   pickupLocation dropoffLocation  carType  rentalAgency  rentalDuration  \
# ...

# %%
final_2.to_csv("2.csv",index=False)
